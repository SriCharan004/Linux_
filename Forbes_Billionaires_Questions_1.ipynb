# %% [markdown]
# <a href="https://colab.research.google.com/github/SriCharan004/Linux_/blob/main/Forbes_Billionaires_Questions_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import io

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b15f060-ff4a-48bc-9cda-66727e4674ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b15f060-ff4a-48bc-9cda-66727e4674ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['Forbes_Billionaire.csv']))
print(df)
# Out:
#       Rank                      Name   Age  Net Worth        Country  \
# 0        1                JEFF BEZOS  56.0      113.0  United States
# 1        2                BILL GATES  64.0       98.0  United States
# 2        3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3        4            WARREN BUFFETT  89.0       67.5  United States
# 4        5             LARRY ELLISON  75.0       59.0  United States
# ...    ...                       ...   ...        ...            ...
# 2090  1990                DAVID HALL  68.0        1.0  United States
# 2091  1990                    DU SHA  73.0        1.0          China
# 2092  1990              WANG YANQING  73.0        1.0          China
# 2093  1990                 XU WANMAO  75.0        1.0          China
# 2094  1990             WANG MIAOTONG  62.0        1.0          China
#
#                      Source             Industries
# 0                    Amazon             Technology
# ...

# %%
df.head(10)
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
# 5     6            AMANCIO ORTEGA  84.0       55.1          Spain
# 6     7           MARK ZUCKERBERG  35.0       54.7  United States
# 7     8                JIM WALTON  71.0       54.6  United States
# 8     9              ALICE WALTON  70.0       54.4  United States
# 9    10                ROB WALTON  75.0       54.1  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2095 non-null   int64
#  1   Name        2095 non-null   object
#  2   Age         2052 non-null   float64
#  3   Net Worth   2095 non-null   float64
#  4   Country     2095 non-null   object
#  5   Source      2095 non-null   object
#  6   Industries  2095 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 114.7+ KB

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ea8415b8a3ee> in <cell line: 1>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
nw=df["Net Worth"]

print("sum is ",nw.sum())
print("average is",np.average(nw))
print("Mean is ",nw.mean())
# Out:
# sum is  8037.499999999999
# average is 3.8365155131264914
# Mean is  3.8365155131264914

# %%
country = df["Country"]

# %%
print("Mode is",country.mode())
print("\nUnique countries are",country.unique())
print("\nNUmber of uniques countires are",country.nunique())
# Out:
# Mode is 0    United States
# Name: Country, dtype: object
#
# Unique countries are ['United States' 'France' 'Spain' 'Mexico' 'China' 'India' 'Germany'
#  'Canada' 'Hong Kong' 'Italy' 'Brazil' 'Russia' 'Japan' 'Austria'
#  'Czechia' 'South Korea' 'Indonesia' 'Sweden' 'Thailand' 'Australia'
#  'United Kingdom' 'Netherlands' 'Singapore' 'Ireland' 'Chile'
#  'New Zealand' 'Cyprus' 'Malaysia' 'Colombia' 'Nigeria' 'Denmark'
#  'Switzerland' 'Belgium' 'Israel' 'South Africa' 'Vietnam' 'Philippines'
#  'Taiwan' 'Egypt' 'Norway' 'Georgia' 'Finland' 'Turkey' 'Algeria' 'Peru'
#  'Portugal' 'Poland' 'Kazakhstan' 'United Arab Emirates' 'Venezuela'
#  'Liechtenstein' 'Greece' 'Argentina' 'Eswatini (Swaziland)' 'Ukraine'
#  'Lebanon' 'Guernsey' 'Oman' 'Iceland' 'Macao' 'Monaco' 'Tanzania'
#  'Slovakia' 'Angola' 'Nepal' 'Romania' 'Kuwait' 'Hungary' 'Qatar'
#  'St. Kitts and Nevis' 'Zimbabwe' 'Morocco']
#
# NUmber of uniques countires are 72

# %%
df["Net Worth"].sort_values().tail(5)
# Out:
# 4     59.0
# 3     67.5
# 2     76.0
# 1     98.0
# 0    113.0
# Name: Net Worth, dtype: float64

# %% [markdown]
# Q2. Name the top 8 industries with maximum count of billionaires

# %%
ind=df["Industries"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-737eddadece3> in <cell line: 1>()
# ----> 1 ind=df["Industries"].unique()
#
# NameError: name 'df' is not defined

# %%
df.groupby('Industries')['Name'].nunique().sort_values(ascending =0).head(8)
# Out:
# Industries
# Finance & Investments    298
# Technology               241
# Fashion & Retail         209
# Manufacturing            198
# Real Estate              196
# Diversified              169
# Food & Beverage          168
# Healthcare               149
# Name: Name, dtype: int64

# %%
df.groupby('Industries')['Net Worth'].mean().sort_values(ascending =0).head(8)
# Out:
# Industries
# Technology               5.634440
# Fashion & Retail         5.372727
# Telecom                  4.941379
# Gambling & Casinos       4.528571
# Metals & Mining          4.193220
# Energy                   4.067500
# Media & Entertainment    3.994595
# Food & Beverage          3.708333
# Name: Net Worth, dtype: float64

# %%
df.groupby('Industries')['Age'].mean().sort_values().head(8)
# Out:
# Industries
# Technology               55.375527
# Metals & Mining          60.913793
# Healthcare               63.088435
# Automotive               63.152174
# Manufacturing            64.139896
# Service                  64.317460
# Telecom                  64.413793
# Media & Entertainment    64.760563
# Name: Age, dtype: float64

# %%
Auto=df['Industries']=='Automotive'

# %%
df[df['Industries']=="Automotive"].sort_values(by = 'Net Worth', ascending = 0).head(5)
# Out:
#      Rank             Name   Age  Net Worth        Country  \
# 30     31        ELON MUSK  48.0       24.6  United States
# 53     54  SUSANNE KLATTEN  57.0       16.8        Germany
# 95     96         LI SHUFU  56.0       12.4          China
# 98     98    STEFAN QUANDT  53.0       12.3        Germany
# 165   165     LU ZHONGFANG  77.0        8.2          China
#
#                    Source  Industries
# 30          Tesla, SpaceX  Automotive
# 53   BMW, pharmaceuticals  Automotive
# 95            automobiles  Automotive
# 98                    BMW  Automotive
# 165             education  Automotive
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %%
pd.DataFrame(df.groupby('Country')['Name'].nunique()).sort_values(by='Name',ascending=0).head(5)
# Out:
#                Name
# Country
# United States   614
# China           387
# Germany         107
# India           102
# Russia           99

# %%
df[df['Country']=='China'].sort_values(by='Net Worth',ascending=0).head(1)
# Out:
#     Rank     Name   Age  Net Worth Country      Source  Industries
# 16    17  JACK MA  55.0       38.8   China  e-commerce  Technology

# %%
df[df['Country']=='India'].groupby('Industries')['Name'].nunique().sort_values(ascending=0).head(5)
# Out:
# Industries
# Healthcare         17
# Manufacturing      14
# Diversified        13
# Technology         11
# Food & Beverage     8
# Name: Name, dtype: int64

# %%
top_100 =df.sort_values(by='Net Worth',ascending=0).head(100)
top_100
# Out:
#     Rank                      Name   Age  Net Worth        Country  \
# 0      1                JEFF BEZOS  56.0      113.0  United States
# 1      2                BILL GATES  64.0       98.0  United States
# 2      3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3      4            WARREN BUFFETT  89.0       67.5  United States
# 4      5             LARRY ELLISON  75.0       59.0  United States
# ..   ...                       ...   ...        ...            ...
# 95    96                  LI SHUFU  56.0       12.4          China
# 96    96   HASSO PLATTNER & FAMILY  76.0       12.4        Germany
# 98    98             STEFAN QUANDT  53.0       12.3        Germany
# 97    98      LIU YONGHAO & FAMILY  68.0       12.3          China
# 99   100               KEN GRIFFIN  51.0       12.1  United States
#
#                 Source             Industries
# 0               Amazon             Technology
# 1            Microsoft             Technology
# ...

# %%
top_in_100=top_100[top_100['Country']=='India']
top_in_100
# Out:
#     Rank                         Name   Age  Net Worth Country  \
# 20    21                MUKESH AMBANI  62.0       36.8   India
# 77    78  RADHAKISHAN DAMANI & FAMILY  65.0       13.8   India
#
#                        Source        Industries
# 20  petrochemicals, oil & gas            Energy
# 77        retail, investments  Fashion & Retail

# %%
IB=df[df['Country']=='India']
IB[IB['Age']<50]
# Out:
#       Rank                  Name   Age  Net Worth Country  \
# 874    875  VIJAY SHEKHAR SHARMA  41.0        2.4   India
# 1196  1196       BYJU RAVEENDRAN  38.0        1.8   India
# 1237  1196          VIKAS OBEROI  49.0        1.8   India
# 1420  1415            RANJAN PAI  47.0        1.5   India
# 1618  1613     SHAMSHEER VAYALIL  43.0        1.3   India
# 1732  1730         SACHIN BANSAL  38.0        1.2   India
# 1742  1730           RADHA VEMBU  47.0        1.2   India
# 1856  1851          BINNY BANSAL  37.0        1.1   India
# 1867  1851    ACHARYA BALKRISHNA  47.0        1.1   India
#
#                     Source        Industries
# 874   financial technology           Service
# 1196  education technology        Technology
# 1237           real estate       Real Estate
# 1420             education           Service
# 1618            healthcare        Healthcare
# 1732              flipkart  Fashion & Retail
# 1742            technology        Technology
# ...

# %%
df[df['Name']=='Donald Trump']
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Age, Net Worth, Country, Source, Industries]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
# ...

# %%
IB_RE=IB[IB['Industries']=='Real Estate']
IB_RE
# Out:
#       Rank                  Name   Age  Net Worth Country       Source  \
# 494    494      KUSHAL PAL SINGH  88.0        3.7   India  real estate
# 774    764        CHANDRU RAHEJA  79.0        2.7   India  real estate
# 1237  1196          VIKAS OBEROI  49.0        1.8   India  real estate
# 1253  1196  MANGAL PRABHAT LODHA  64.0        1.8   India  real estate
# 1395  1335      JITENDRA VIRWANI  54.0        1.6   India  real estate
# 1712  1613  NIRANJAN HIRANANDANI  70.0        1.3   India  real estate
# 1716  1613        SUBHASH RUNWAL  76.0        1.3   India  real estate
# 1983  1851        MOFATRAJ MUNOT  75.0        1.1   India  real estate
#
#        Industries
# 494   Real Estate
# 774   Real Estate
# 1237  Real Estate
# 1253  Real Estate
# 1395  Real Estate
# 1712  Real Estate
# 1716  Real Estate
# 1983  Real Estate

# %%
IB_RE[IB_RE['Net Worth']>df[df['Name']=='DONALD TRUMP'].values[0][3]]
# Out:
#      Rank              Name   Age  Net Worth Country       Source   Industries
# 494   494  KUSHAL PAL SINGH  88.0        3.7   India  real estate  Real Estate
# 774   764    CHANDRU RAHEJA  79.0        2.7   India  real estate  Real Estate

# %%
df['Net worth']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Net worth'
#
# The above exception was the direct cause of the following exception:
#
# ...
